# %%
import pandas as pd
df=pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Pclass     Sex   Age     Fare  Survived
# 0       3    male  22.0   7.2500         0
# 1       1  female  38.0  71.2833         1
# 2       3  female  26.0   7.9250         1
# 3       1  female  35.0  53.1000         1
# 4       3    male  35.0   8.0500         0

# %%
target=df.Survived
inputs=df.drop('Survived',axis='columns')

# %%
dummies=pd.get_dummies(inputs.Sex,dtype=int)
dummies.head()
# Out:
#    female  male
# 0       0     1
# 1       1     0
# 2       1     0
# 3       1     0
# 4       0     1

# %%
inputs = pd.concat([inputs,dummies],axis='columns')
inputs.head()
# Out:
#    Pclass     Sex   Age     Fare  female   male  female  male  female  male
# 0       3    male  22.0   7.2500   False   True       0     1       0     1
# 1       1  female  38.0  71.2833    True  False       1     0       1     0
# 2       3  female  26.0   7.9250    True  False       1     0       1     0
# 3       1  female  35.0  53.1000    True  False       1     0       1     0
# 4       3    male  35.0   8.0500   False   True       0     1       0     1

# %%
inputs.drop(['Sex','male'],axis='columns',inplace=True)
inputs.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44596\1680350098.py in ?()
# ----> 1 inputs.drop(['Sex','male'],axis='columns',inplace=True)
#       2 inputs.head()
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4784         obj = self
#    4785
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#    4791             self._update_inplace(obj)
#
# ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\generic.py in ?(self, labels, axis, level, errors, only_slice)
#    4855                 mask = ~axis.isin(labels)
#    4856                 # Check if label doesn't exist along axis
#    4857                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4858                 if errors == "raise" and labels_missing:
# -> 4859                     raise KeyError(f"{labels} not found in axis")
#    4860
#    4861             if isinstance(mask.dtype, ExtensionDtype):
#    4862                 # GH#45860
#
# KeyError: "['Sex' 'male'] not found in axis"

# %%
inputs.columns[inputs.isna().any()]
# Out:
# Index(['Age'], dtype='object')

# %%
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())
inputs.head()
# Out:
#    Pclass   Age     Fare  female  female  female
# 0       3  22.0   7.2500   False       0       0
# 1       1  38.0  71.2833    True       1       1
# 2       3  26.0   7.9250    True       1       1
# 3       1  35.0  53.1000    True       1       1
# 4       3  35.0   8.0500   False       0       0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.7798507462686567

# %%
X_test[0:10]
# Out:
#      Pclass        Age     Fare  female  female  female
# 777       3   5.000000  12.4750    True       1       1
# 599       1  49.000000  56.9292   False       0       0
# 593       3  29.699118   7.7500    True       1       1
# 846       3  29.699118  69.5500   False       0       0
# 875       3  15.000000   7.2250    True       1       1
# 256       1  29.699118  79.2000    True       1       1
# 239       2  33.000000  12.2750   False       0       0
# 565       3  24.000000  24.1500   False       0       0
# 672       2  70.000000  10.5000   False       0       0
# 463       2  48.000000  13.0000   False       0       0

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[3.67061646e-03, 9.96329384e-01],
#        [9.65218790e-01, 3.47812100e-02],
#        [7.41849553e-03, 9.92581504e-01],
#        [9.92435280e-01, 7.56471959e-03],
#        [5.40760000e-03, 9.94592400e-01],
#        [1.44047178e-04, 9.99855953e-01],
#        [9.96040350e-01, 3.95964956e-03],
#        [9.97940208e-01, 2.05979239e-03],
#        [9.89100081e-01, 1.08999190e-02],
#        [9.95482804e-01, 4.51719641e-03]])
